# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from user_pkg import graph
import importlib

importlib.reload(graph)
# Out:
# <module 'user_pkg.graph' from 'c:\\EXAM_PYTHON\\KDT-mini_project-07\\이현길\\user_pkg\\graph.py'>

# %%
pubg_duoDF_ori: pd.DataFrame = pd.read_pickle("./DataFrame/pubg_duoDF.pkl")
pubg_duo_fppDF_ori: pd.DataFrame = pd.read_pickle("./DataFrame/pubg_duo_fppDF.pkl")

# %%
pubg_duoDF_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313591 entries, 2 to 4446955
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   assists          313591 non-null  uint8
#  1   boosts           313591 non-null  uint8
#  2   damageDealt      313591 non-null  float64
#  3   DBNOs            313591 non-null  uint8
#  4   headshotKills    313591 non-null  uint8
#  5   heals            313591 non-null  uint8
#  6   killPlace        313591 non-null  uint8
#  7   killPoints       313591 non-null  uint16
#  8   kills            313591 non-null  uint8
#  9   killStreaks      313591 non-null  uint8
#  10  longestKill      313591 non-null  float64
#  11  matchDuration    313591 non-null  uint16
#  12  maxPlace         313591 non-null  uint8
#  13  numGroups        313591 non-null  uint8
#  14  revives          313591 non-null  uint8
#  15  rideDistance     313591 non-null  float64
# ...

# %%
pubg_duo_fppDF_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 996691 entries, 11 to 4446958
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   assists          996691 non-null  uint8
#  1   boosts           996691 non-null  uint8
#  2   damageDealt      996691 non-null  float64
#  3   DBNOs            996691 non-null  uint8
#  4   headshotKills    996691 non-null  uint8
#  5   heals            996691 non-null  uint8
#  6   killPlace        996691 non-null  uint8
#  7   killPoints       996691 non-null  uint16
#  8   kills            996691 non-null  uint8
#  9   killStreaks      996691 non-null  uint8
#  10  longestKill      996691 non-null  float64
#  11  matchDuration    996691 non-null  uint16
#  12  maxPlace         996691 non-null  uint8
#  13  numGroups        996691 non-null  uint8
#  14  revives          996691 non-null  uint8
#  15  rideDistance     996691 non-null  float64
# ...

# %%
drop_features_low_connection = [
    "killPoints",
    "kills",
    "maxPlace",
    # "numGroups",
    "rideDistance",
    "roadKills",
    "swimDistance",
    "vehicleDestroys",
]

# %%
pubg_duoDF = pubg_duoDF_ori.drop(drop_features_low_connection, axis=1)
pubg_duo_fppDF = pubg_duo_fppDF_ori.drop(drop_features_low_connection, axis=1)

# %%
graph.draw_hist_all(pubg_duoDF, 100, "log")

# %%
pubg_duoDF.corr()["winPlacePerc"].sort_values(ascending=False)
# Out:
# winPlacePerc       1.000000
# walkDistance       0.823122
# boosts             0.646184
# weaponsAcquired    0.627273
# damageDealt        0.470270
# heals              0.444117
# longestKill        0.409913
# killStreaks        0.403929
# DBNOs              0.353330
# assists            0.326466
# headshotKills      0.288519
# revives            0.252894
# winRankPoints      0.197391
# teamKills          0.021557
# numGroups          0.017087
# matchDuration      0.000153
# killPlace         -0.747252
# Name: winPlacePerc, dtype: float64

# %%
graph.draw_hist_all(pubg_duo_fppDF, 100, "log")

# %%
pubg_duo_fppDF.corr()["winPlacePerc"].sort_values(ascending=False)
# Out:
# winPlacePerc       1.000000
# walkDistance       0.834562
# weaponsAcquired    0.658328
# boosts             0.650331
# damageDealt        0.478546
# heals              0.449574
# longestKill        0.430427
# killStreaks        0.406523
# DBNOs              0.360758
# assists            0.322249
# headshotKills      0.303001
# revives            0.268611
# winRankPoints      0.181139
# teamKills          0.027945
# numGroups          0.014006
# matchDuration      0.000026
# killPlace         -0.745591
# Name: winPlacePerc, dtype: float64

# %%
graph.draw_hist("weaponsAcquired", pubg_duoDF, 100, "log")

# %%
weaponsAcquired_mask = pubg_duoDF["weaponsAcquired"] < 25

# %%
graph.draw_hist("weaponsAcquired", pubg_duoDF[weaponsAcquired_mask], 100, "log")

# %%
graph.draw_hist("weaponsAcquired", pubg_duo_fppDF, 100, "log")

# %%
weaponsAcquired_mask_fpp = pubg_duo_fppDF["weaponsAcquired"] < 25

# %%
graph.draw_hist("weaponsAcquired", pubg_duo_fppDF[weaponsAcquired_mask_fpp], 100, "log")

# %%
graph.draw_hist_all(pubg_duoDF[weaponsAcquired_mask], 100, "log")

# %%
graph.draw_hist_all(pubg_duo_fppDF[weaponsAcquired_mask_fpp], 100, "log")
